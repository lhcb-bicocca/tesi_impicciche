# %% [markdown]
# # Example notebook
#
# This example notebook shows how to use libraries from this of dependent packages

# %%
from mypkg.library import myfunc

# %%
myfunc()
# Out:
# Hello from myfunc!

# %%
from analysis_helpers.efficiency import binomial_error

# %%
binomial_error(0.1, 100)
# Out:
# np.float64(3.0000000000000004)

# %%
import numpy as np

# %%
x =np.random.normal(0, 1, 1000)

# %%
from analysis_helpers.plotting import plot_hist

# %%
fig, ax = plot_hist(x, bins=50, range=(-4,4), xlabel='x', name='X', unit='a.u.')
